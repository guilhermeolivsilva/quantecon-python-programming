# %% [markdown]
# # Task: plotting a White Noise process

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Version 1

# %%
ϵ_values = np.random.randn(100)
plt.plot(ϵ_values)

plt.show()
ϵ_values[1:5]
# Out:
# array([-0.29327402, -0.49639324,  0.18545761,  0.11095594])

# %% [markdown]
# ## Implementing with a for loop

# %%
ts_length = 100
ϵ_values = []   # empty list

for i in range(ts_length):
    e = np.random.randn()
    ϵ_values.append(e)

plt.plot(ϵ_values)
plt.show()

ϵ_values[1:5]
# Out:
# [-1.9374024696728098,
#  0.189622573865905,
#  0.6705542110335077,
#  0.5089218428754521]

# %% [markdown]
# ## Implementing with a while loop

# %%
ts_length = 100
ϵ_values = []
i = 0
while i < ts_length:
    e = np.random.randn()
    ϵ_values.append(e)
    i = i + 1
plt.plot(ϵ_values)
plt.show()

ϵ_values[1:5]
# Out:
# [0.5248735238978595,
#  0.007242565641555414,
#  -0.8133512936260276,
#  -0.25918977868058]

# %% [markdown]
# ## Another application
# Plotting the balance of a bank account that yields interest.

# %%
r = 0.025         # interest rate
T = 50            # end date
b = np.empty(T+1) # an empty NumPy array, to store all b_t
b[0] = 10         # initial balance

for t in range(T):
    b[t+1] = (1 + r) * b[t]

plt.plot(b, label='bank balance')
plt.legend()
plt.show()
